# %% [markdown]
# <a href="https://colab.research.google.com/github/mashaan14/YouTube-channel/blob/main/2023_12_04_GCN_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Convolutional Networks (GCNs)
#
# I borrowed some code from these resources:
#   - https://github.com/tkipf/pygcn/tree/master
#   - https://lightning.ai/docs/pytorch/stable/notebooks/course_UvA-DL/06-graph-neural-networks.html
#
# For any questions about this notebook, please email me on __[mashaan.awad@outlook.com](mailto:mashaan.awad@outlook.com)__

# %% [markdown]
# ## Prepare libraries and data

# %%
# !pip install torch-geometric
# Out:
# Collecting torch-geometric
#   Downloading torch_geometric-2.4.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (4.66.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch-geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (3.2.0)
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.4.0

# %%
# Standard libraries
import math
import time
import numpy as np
import pandas as pd

# Plotting libraries
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib import cm

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# PyTorch geometric
import torch_geometric
from torch_geometric.datasets import StochasticBlockModelDataset
from torch_geometric.utils import to_networkx
from torch_geometric.utils import to_dense_adj
from torch_geometric.transforms import RandomNodeSplit

# %%
num_nodes_per_class = 100
num_nodes = [num_nodes_per_class] * 3
edge_probs = [[0.1, 0.05, 0.02],
              [0.05, 0.1, 0.02],
              [0.02, 0.02, 0.1]]
dataset = StochasticBlockModelDataset('/content', num_nodes, edge_probs, num_channels=10)
# Out:
# Processing...
# Done!

# %%
colors = cm.tab10.colors
y_colors = np.array(colors)[dataset[0].y.numpy()]

# %%
dataset[0]
# Out:
# Data(x=[300, 10], edge_index=[2, 4782], y=[300])

# %%
G = to_networkx(dataset[0], to_undirected=True)
node_pos=nx.spring_layout(G, seed=0)
plt.figure(figsize=(8,8))
plt.axis('off')
nx.draw_networkx_nodes(G,
                pos=node_pos,
                node_size=200,
                node_color=y_colors,
                alpha=0.9
                )
nx.draw_networkx_edges(G,
                pos=node_pos,
                edge_color="grey",
                alpha=0.2
                )
plt.show()

# %%
split = RandomNodeSplit(num_val=0.1, num_test=0.1)
data = split(dataset[0])
data
# Out:
# Data(x=[300, 10], edge_index=[2, 4782], y=[300], train_mask=[300], val_mask=[300], test_mask=[300])

# %% [markdown]
# ## GCN

# %%
# layers.py

class GraphConvolution(nn.Module):
    """
    Simple GCN layer, similar to https://arxiv.org/abs/1609.02907
    """

    def __init__(self, in_features, out_features, bias=True):
        super(GraphConvolution, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.FloatTensor(in_features, out_features))
        if bias:
            self.bias = nn.Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adj):
        support = torch.mm(input, self.weight)
        output = torch.spmm(adj, support)
        if self.bias is not None:
            return output + self.bias
        else:
            return output

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_features) + ' -> ' \
               + str(self.out_features) + ')'

# %%
# models.py

class GCN(nn.Module):
    def __init__(self, nfeat, nhid, nclass, dropout):
        super(GCN, self).__init__()

        self.gc1 = GraphConvolution(nfeat, nhid) # nfeat = 10, nhid = 3
        self.gc2 = GraphConvolution(nhid, nclass) # nhid = 3, nclass = 3
        self.dropout = dropout

    def forward(self, x, adj):
        x = F.relu(self.gc1(x, adj))
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.gc2(x, adj)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# ## Training

# %%
adj = to_dense_adj(data.edge_index)[0]
# build symmetric adjacency matrix
adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
adj = adj + torch.eye(adj.shape[0])

features = data.x
labels = data.y
idx_train = data.train_mask
idx_val = data.val_mask
idx_test = data.test_mask

# %%
model = GCN(nfeat=features.shape[1],
            nhid=3, # Number of hidden units
            nclass=labels.max().item() + 1,
            dropout=0.5)
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

# %%
def accuracy(output, labels):
    preds = output.max(1)[1].type_as(labels)
    correct = preds.eq(labels).double()
    correct = correct.sum()
    return correct / len(labels)

# %%
loss_train_list = []
loss_val_list = []

for epoch in range(1000):
    model.train()
    optimizer.zero_grad()
    output = model(features, adj)
    loss_train = F.nll_loss(output[idx_train], labels[idx_train])
    loss_train_list.append(loss_train.item())
    acc_train = accuracy(output[idx_train], labels[idx_train])
    loss_train.backward()
    optimizer.step()

    # Evaluate validation set performance separately,
    # deactivates dropout during validation run.
    model.eval()
    output = model(features, adj)
    loss_val = F.nll_loss(output[idx_val], labels[idx_val])
    loss_val_list.append(loss_val.item())
    acc_val = accuracy(output[idx_val], labels[idx_val])

    # Print evaluation metrics every 10 epochs
    if epoch % 10 == 0:
        print(f'Epoch {epoch:>3} | Train Acc: {acc_train.item()*100:.2f}% | Validation Acc: {acc_val.item()*100:.2f}%')
# Out:
# Epoch   0 | Train Acc: 36.67% | Validation Acc: 36.67%
# Epoch  10 | Train Acc: 48.33% | Validation Acc: 33.33%
# Epoch  20 | Train Acc: 41.67% | Validation Acc: 33.33%
# Epoch  30 | Train Acc: 45.42% | Validation Acc: 33.33%
# Epoch  40 | Train Acc: 55.42% | Validation Acc: 53.33%
# Epoch  50 | Train Acc: 59.58% | Validation Acc: 46.67%
# Epoch  60 | Train Acc: 58.33% | Validation Acc: 56.67%
# Epoch  70 | Train Acc: 65.83% | Validation Acc: 46.67%
# Epoch  80 | Train Acc: 59.17% | Validation Acc: 46.67%
# Epoch  90 | Train Acc: 55.00% | Validation Acc: 50.00%
# Epoch 100 | Train Acc: 67.08% | Validation Acc: 56.67%
# Epoch 110 | Train Acc: 67.92% | Validation Acc: 50.00%
# Epoch 120 | Train Acc: 62.08% | Validation Acc: 53.33%
# Epoch 130 | Train Acc: 62.92% | Validation Acc: 50.00%
# Epoch 140 | Train Acc: 67.08% | Validation Acc: 53.33%
# Epoch 150 | Train Acc: 66.67% | Validation Acc: 56.67%
# Epoch 160 | Train Acc: 67.92% | Validation Acc: 53.33%
# Epoch 170 | Train Acc: 60.00% | Validation Acc: 53.33%
# Epoch 180 | Train Acc: 66.67% | Validation Acc: 56.67%
# Epoch 190 | Train Acc: 70.00% | Validation Acc: 66.67%
# Epoch 200 | Train Acc: 70.42% | Validation Acc: 66.67%
# Epoch 210 | Train Acc: 64.58% | Validation Acc: 60.00%
# Epoch 220 | Train Acc: 71.25% | Validation Acc: 63.33%
# Epoch 230 | Train Acc: 72.50% | Validation Acc: 60.00%
# Epoch 240 | Train Acc: 64.17% | Validation Acc: 66.67%
# Epoch 250 | Train Acc: 71.25% | Validation Acc: 66.67%
# Epoch 260 | Train Acc: 70.42% | Validation Acc: 66.67%
# Epoch 270 | Train Acc: 67.92% | Validation Acc: 66.67%
# Epoch 280 | Train Acc: 70.83% | Validation Acc: 70.00%
# Epoch 290 | Train Acc: 74.17% | Validation Acc: 66.67%
# Epoch 300 | Train Acc: 69.58% | Validation Acc: 66.67%
# Epoch 310 | Train Acc: 73.33% | Validation Acc: 60.00%
# Epoch 320 | Train Acc: 72.92% | Validation Acc: 66.67%
# Epoch 330 | Train Acc: 67.92% | Validation Acc: 70.00%
# Epoch 340 | Train Acc: 64.17% | Validation Acc: 66.67%
# Epoch 350 | Train Acc: 70.83% | Validation Acc: 70.00%
# Epoch 360 | Train Acc: 72.08% | Validation Acc: 70.00%
# Epoch 370 | Train Acc: 75.83% | Validation Acc: 70.00%
# Epoch 380 | Train Acc: 70.83% | Validation Acc: 70.00%
# Epoch 390 | Train Acc: 72.50% | Validation Acc: 70.00%
# Epoch 400 | Train Acc: 68.75% | Validation Acc: 66.67%
# Epoch 410 | Train Acc: 70.83% | Validation Acc: 66.67%
# Epoch 420 | Train Acc: 72.50% | Validation Acc: 70.00%
# Epoch 430 | Train Acc: 71.25% | Validation Acc: 63.33%
# Epoch 440 | Train Acc: 72.50% | Validation Acc: 70.00%
# Epoch 450 | Train Acc: 78.75% | Validation Acc: 76.67%
# Epoch 460 | Train Acc: 73.75% | Validation Acc: 76.67%
# Epoch 470 | Train Acc: 74.58% | Validation Acc: 73.33%
# Epoch 480 | Train Acc: 79.58% | Validation Acc: 73.33%
# Epoch 490 | Train Acc: 77.08% | Validation Acc: 73.33%
# Epoch 500 | Train Acc: 66.25% | Validation Acc: 76.67%
# Epoch 510 | Train Acc: 74.58% | Validation Acc: 76.67%
# Epoch 520 | Train Acc: 77.08% | Validation Acc: 76.67%
# Epoch 530 | Train Acc: 79.17% | Validation Acc: 76.67%
# Epoch 540 | Train Acc: 75.00% | Validation Acc: 76.67%
# Epoch 550 | Train Acc: 79.17% | Validation Acc: 76.67%
# Epoch 560 | Train Acc: 77.50% | Validation Acc: 70.00%
# Epoch 570 | Train Acc: 75.83% | Validation Acc: 83.33%
# Epoch 580 | Train Acc: 74.58% | Validation Acc: 90.00%
# Epoch 590 | Train Acc: 77.50% | Validation Acc: 83.33%
# Epoch 600 | Train Acc: 71.25% | Validation Acc: 70.00%
# Epoch 610 | Train Acc: 78.75% | Validation Acc: 83.33%
# Epoch 620 | Train Acc: 78.75% | Validation Acc: 93.33%
# Epoch 630 | Train Acc: 79.58% | Validation Acc: 93.33%
# Epoch 640 | Train Acc: 82.08% | Validation Acc: 83.33%
# Epoch 650 | Train Acc: 77.50% | Validation Acc: 70.00%
# Epoch 660 | Train Acc: 73.33% | Validation Acc: 80.00%
# Epoch 670 | Train Acc: 80.42% | Validation Acc: 93.33%
# Epoch 680 | Train Acc: 80.00% | Validation Acc: 80.00%
# Epoch 690 | Train Acc: 82.50% | Validation Acc: 80.00%
# Epoch 700 | Train Acc: 78.75% | Validation Acc: 93.33%
# Epoch 710 | Train Acc: 81.67% | Validation Acc: 93.33%
# Epoch 720 | Train Acc: 80.83% | Validation Acc: 93.33%
# Epoch 730 | Train Acc: 79.58% | Validation Acc: 86.67%
# Epoch 740 | Train Acc: 85.83% | Validation Acc: 96.67%
# Epoch 750 | Train Acc: 81.25% | Validation Acc: 93.33%
# Epoch 760 | Train Acc: 85.00% | Validation Acc: 70.00%
# Epoch 770 | Train Acc: 82.08% | Validation Acc: 73.33%
# Epoch 780 | Train Acc: 84.17% | Validation Acc: 86.67%
# Epoch 790 | Train Acc: 81.25% | Validation Acc: 96.67%
# Epoch 800 | Train Acc: 81.67% | Validation Acc: 80.00%
# Epoch 810 | Train Acc: 79.58% | Validation Acc: 73.33%
# Epoch 820 | Train Acc: 85.42% | Validation Acc: 80.00%
# Epoch 830 | Train Acc: 82.92% | Validation Acc: 96.67%
# Epoch 840 | Train Acc: 77.08% | Validation Acc: 80.00%
# Epoch 850 | Train Acc: 83.33% | Validation Acc: 96.67%
# Epoch 860 | Train Acc: 80.00% | Validation Acc: 96.67%
# Epoch 870 | Train Acc: 84.58% | Validation Acc: 73.33%
# Epoch 880 | Train Acc: 85.42% | Validation Acc: 93.33%
# Epoch 890 | Train Acc: 81.25% | Validation Acc: 96.67%
# Epoch 900 | Train Acc: 81.67% | Validation Acc: 93.33%
# Epoch 910 | Train Acc: 82.92% | Validation Acc: 93.33%
# Epoch 920 | Train Acc: 82.08% | Validation Acc: 76.67%
# Epoch 930 | Train Acc: 81.67% | Validation Acc: 93.33%
# Epoch 940 | Train Acc: 85.83% | Validation Acc: 93.33%
# Epoch 950 | Train Acc: 85.00% | Validation Acc: 86.67%
# Epoch 960 | Train Acc: 84.58% | Validation Acc: 76.67%
# Epoch 970 | Train Acc: 77.92% | Validation Acc: 93.33%
# Epoch 980 | Train Acc: 79.58% | Validation Acc: 96.67%
# Epoch 990 | Train Acc: 82.92% | Validation Acc: 93.33%

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.plot(loss_train_list)
ax1.set_title('Training loss')
ax2.plot(loss_val_list)
ax2.set_title('Validation loss')
plt.show()

# %% [markdown]
# ## Testing

# %%
model.eval()
output = model(features, adj)
loss_test = F.nll_loss(output[idx_test], labels[idx_test])
idx_test_preds = output[idx_test].max(1)[1].type_as(labels)
acc_test = accuracy(output[idx_test], labels[idx_test])
print(f'Test Acc: {acc_test.item()*100:.2f}% | Test loss: {loss_test.item():.2f}')
# Out:
# Test Acc: 90.00% | Test loss: 0.35

# %%
torch.sum(labels[idx_test]!=idx_test_preds).item()
# Out:
# 3

# %%
G1 = nx.from_numpy_array(adj.numpy())
node_pos=nx.spring_layout(G, seed=0)

idx_train_nodes = np.nonzero(idx_train.numpy())[0]
idx_val_nodes = np.nonzero(idx_val.numpy())[0]
idx_test_nodes = np.nonzero(idx_test.numpy())[0]

idx_train_graph = G.subgraph(idx_train_nodes.tolist())
idx_val_graph = G.subgraph(idx_val_nodes.tolist())

idx_test_graph = G.subgraph(idx_test_nodes.tolist())
idx_test_graph_colors_true = np.array(colors)[labels[idx_test]]
idx_test_graph_colors_preds = np.array(colors)[idx_test_preds]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
ax1.set_title('True labels')
nx.draw_networkx_nodes(idx_train_graph,
                pos=node_pos,
                node_size=200,
                node_color='grey',
                alpha=0.15,
                ax = ax1
                )
nx.draw_networkx_nodes(idx_val_graph,
                pos=node_pos,
                node_size=200,
                node_color='grey',
                alpha=0.15,
                ax = ax1
                )
nx.draw_networkx_nodes(idx_test_graph,
                pos=node_pos,
                node_size=200,
                node_color=idx_test_graph_colors_true,
                alpha=0.9,
                ax = ax1
                )

ax2.set_title('Predicted labels')
nx.draw_networkx_nodes(idx_train_graph,
                pos=node_pos,
                node_size=200,
                node_color='grey',
                alpha=0.15,
                ax = ax2
                )
nx.draw_networkx_nodes(idx_val_graph,
                pos=node_pos,
                node_size=200,
                node_color='grey',
                alpha=0.15,
                ax = ax2
                )
nx.draw_networkx_nodes(idx_test_graph,
                pos=node_pos,
                node_size=200,
                node_color=idx_test_graph_colors_preds,
                alpha=0.9,
                ax = ax2
                )

plt.show()

# %%
model
# Out:
# GCN(
#   (gc1): GraphConvolution (10 -> 3)
#   (gc2): GraphConvolution (3 -> 3)
# )

# %%
embeddings = F.relu(model.gc1(features, adj)).detach().numpy()
embeddings.shape
# Out:
# (300, 3)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(embeddings[:,0], embeddings[:,1], embeddings[:,2], color=y_colors)
plt.show()

# %%
G = to_networkx(dataset[0], to_undirected=True)
node_pos=nx.spring_layout(G, seed=0)
plt.figure(figsize=(8,8))
plt.axis('off')
nx.draw_networkx_nodes(G,
                pos=node_pos,
                node_size=200,
                node_color=y_colors,
                alpha=0.9
                )
nx.draw_networkx_edges(G,
                pos=node_pos,
                edge_color="grey",
                alpha=0.2
                )
plt.savefig('plot-01.png', bbox_inches='tight', dpi=600)

# %%
plt.figure(figsize=(8,8))
plt.axis('off')
nx.draw_networkx_nodes(idx_train_graph,
                pos=node_pos,
                node_size=200,
                node_color='grey',
                alpha=0.15
                )
nx.draw_networkx_nodes(idx_val_graph,
                pos=node_pos,
                node_size=200,
                node_color='grey',
                alpha=0.15
                )
nx.draw_networkx_nodes(idx_test_graph,
                pos=node_pos,
                node_size=200,
                node_color=idx_test_graph_colors_preds,
                alpha=0.9
                )

plt.savefig('plot-02.png', bbox_inches='tight', dpi=600)

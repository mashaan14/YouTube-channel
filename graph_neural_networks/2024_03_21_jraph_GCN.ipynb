# %% [markdown]
# <a href="https://colab.research.google.com/github/mashaan14/YouTube-channel/blob/main/notebooks/2024_03_21_jraph_GCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Convolutional Network (GCN) in JAX
#
# ## YouTube:
# I explained this notebook in a [YouTube video](https://youtu.be/O1zGWMEgW7A).
#
# ## Acknowledgment:
# I borrowed some code from [Introduction to Graph Neural Nets with JAX/jraph](https://colab.research.google.com/github/deepmind/educational/blob/master/colabs/summer_schools/intro_to_graph_nets_tutorial_with_jraph.ipynb#scrollTo=1n1kCuqtkvfm) and [pytorch-geometric tutorials](https://pytorch-geometric.readthedocs.io/en/latest/get_started/colabs.html).
#
# ## References:
# ```bibtex
# @inproceedings{Fey/Lenssen/2019,
#   title={Fast Graph Representation Learning with {PyTorch Geometric}},
#   author={Fey, Matthias and Lenssen, Jan E.},
#   booktitle={ICLR Workshop on Representation Learning on Graphs and Manifolds},
#   year={2019},
# }
# ```
#
# ```bibtex
# @software{jraph2020github,
#   author = {Jonathan Godwin* and Thomas Keck* and Peter Battaglia and Victor Bapst and Thomas Kipf and Yujia Li and Kimberly Stachenfeld and Petar Veli\v{c}kovi\'{c} and Alvaro Sanchez-Gonzalez},
#   title = {{J}raph: {A} library for graph neural networks in jax.},
#   url = {http://github.com/deepmind/jraph},
#   version = {0.0.1.dev},
#   year = {2020},
# }
# ```

# %% [markdown]
# ##DL and GNN libraries

# %% [markdown]
# ![notes_Page_1.png](data:image/png;base64,...)

# %% [markdown]
# ## PyG vs Jraph

# %% [markdown]
# ![notes_Page_2.png](data:image/png;base64,...)

# %% [markdown]
# Here are the libraries you need to code GCN in pytorch or jax:

# %% [markdown]
# ![notes.png](data:image/png;base64,...)

# %% [markdown]
# The original GCN algorithm uses two layers as shown in equation (9) by Kipf et al. (2017) in https://arxiv.org/abs/1609.02907

# %% [markdown]
# ![notes-02.png](data:image/png;base64,...)

# %% [markdown]
# ## Import libraries

# %%
# install pytorch_geometric
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# install jraph and jax dependencies
# !pip install git+https://github.com/deepmind/jraph.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done
# Collecting git+https://github.com/deepmind/jraph.git
#   Cloning https://github.com/deepmind/jraph.git to /tmp/pip-req-build-youu8s17
#   Running command git clone --filter=blob:none --quiet https://github.com/deepmind/jraph.git /tmp/pip-req-build-youu8s17
#   Resolved https://github.com/deepmind/jraph.git to commit 51f5990104f7374492f8f3ea1cbc47feb411c69c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jax>=0.1.55 in /usr/local/lib/python3.10/dist-packages (from jraph==0.0.6.dev0) (0.4.26)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.10/dist-packages (from jraph==0.0.6.dev0) (0.4.26+cuda12.cudnn89)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from jraph==0.0.6.dev0) (1.25.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.1.55->jraph==0.0.6.dev0) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.1.55->jraph==0.0.6.dev0) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax>=0.1.55->jraph==0.0.6.dev0) (1.11.4)
# Building wheels for collected packages: jraph
#   Building wheel for jraph (setup.py) ... done
#   Created wheel for jraph: filename=jraph-0.0.6.dev0-py3-none-any.whl size=91246 sha256=85c174de8d88aa6f3dc2b5ea9e494f912b7e9f48f4193d8e269a2945006a310e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3yrnkpkw/wheels/76/61/34/8fb9aa4dac00d471de4a5f7157614181de683c445fc2d640db
# Successfully built jraph
# Installing collected packages: jraph
# Successfully installed jraph-0.0.6.dev0

# %%
# Standard libraries
import numpy as np
from scipy import sparse
import seaborn as sns
import pandas as pd

# Plotting libraries
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib import cm
from IPython.display import Javascript  # Restrict height of output cell.

# sklearn
from sklearn.manifold import TSNE

# PyTorch
import torch
import torch.nn.functional as F
from torch.nn import Linear

# PyTorch geometric
from torch_geometric.utils import from_scipy_sparse_matrix
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import (Planetoid, KarateClub)
from torch_geometric.transforms import NormalizeFeatures
from torch_geometric.data import Data
from torch_geometric import seed_everything

# jax
import jax
import jax.numpy as jnp
import jax.tree_util as tree
import flax
import flax.linen as nn
from flax.training import train_state
import optax
import pickle

# jraph
import jraph
from jraph._src import models as jraph_models

# %%
random_seed = 42
plt.style.use('dark_background')
plot_colors = cm.tab10.colors
accuracy_list = []

# %% [markdown]
# ## Import Cora Dataset
# You can find a description of this dataset in [Pytorch-Geometric documentation](https://pytorch-geometric.readthedocs.io/en/latest/generated/torch_geometric.datasets.Planetoid.html#torch_geometric.datasets.Planetoid). In case of `split='full'`, all nodes except those in the validation and test sets will be used for training.

# %%
dataset = Planetoid(root='data/Planetoid', name='Cora', split='full', transform=NormalizeFeatures())
num_features = dataset.num_features
num_classes = dataset.num_classes
data_Cora = dataset[0]  # Get the first graph object.
data_Cora
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])

# %%
graph = jraph.GraphsTuple(
      n_node=jnp.asarray([data_Cora.x.shape[0]]),
      n_edge=jnp.asarray([data_Cora.edge_index.shape[1]]),
      nodes=jnp.asarray(data_Cora.x),
      # No edge features.
      edges=None,
      globals=None,
      senders=jnp.asarray([data_Cora.edge_index[0,:]]).squeeze(),
      receivers=jnp.asarray([data_Cora.edge_index[1,:]]).squeeze())

graph_train_mask = jnp.asarray([data_Cora.train_mask]).squeeze()
graph_val_mask = jnp.asarray([data_Cora.val_mask]).squeeze()
graph_test_mask = jnp.asarray([data_Cora.test_mask]).squeeze()
graph_labels = jnp.asarray([data_Cora.y]).squeeze()
one_hot_labels = jax.nn.one_hot(graph_labels, len(jnp.unique(graph_labels)))

# %% [markdown]
# Let's check if we have the right number of nodes and edges. We also want to check if we have the correct data types `float32` instead of `torch.float32`

# %%
print(f'Number of nodes: {graph.n_node[0]}')
print(f'Number of edges: {graph.n_edge[0]}')
print(f'Feature matrix data type: {graph.nodes.dtype}')
print(f'senders list data type:   {graph.senders.dtype}')
print(f'receivers list data type: {graph.receivers.dtype}')
print(f'Labels matrix data type:  {graph_labels.dtype}')
# Out:
# Number of nodes: 2708
# Number of edges: 10556
# Feature matrix data type: float32
# senders list data type:   int32
# receivers list data type: int32
# Labels matrix data type:  int32

# %% [markdown]
# ## GCN Layers from Jraph

# %%
# Functions must be passed to jraph GNNs, but pytype does not recognise
# linen Modules as callables to here we wrap in a function.
def make_embed_fn(latent_size):
  def embed(inputs):
    return nn.Dense(latent_size)(inputs)
  return embed

def _attention_logit_fn(sender_attr: jnp.ndarray,
                        receiver_attr: jnp.ndarray,
                        edges: jnp.ndarray) -> jnp.ndarray:
  del edges
  x = jnp.concatenate((sender_attr, receiver_attr), axis=1)
  return nn.Dense(1)(x)

# %%
class GCN(nn.Module):
  """Defines a GAT network using FLAX

  Args:
    graph: GraphsTuple the network processes.

  Returns:
    output graph with updated node values.
  """
  gcn1_output_dim: int
  output_dim: int

  @nn.compact
  def __call__(self, x):
    gcn1 = jraph.GraphConvolution(update_node_fn=lambda n: jax.nn.relu(make_embed_fn(self.gcn1_output_dim)(n)),
                          add_self_edges=True)
    gcn2 = jraph.GraphConvolution(update_node_fn=nn.Dense(self.output_dim))
    return gcn2(gcn1(x))

# %%
model = GCN(8, len(jnp.unique(graph_labels)))
model
# Out:
# GCN(
#     # attributes
#     gcn1_output_dim = 8
#     output_dim = 7
# )

# %% [markdown]
# ## Optimizer and Loss
# We set the optimizer to adam using `optax` library. Then we initialized the model using random parameters.

# %%
optimizer = optax.adam(learning_rate=0.01)

rng, inp_rng, init_rng = jax.random.split(jax.random.PRNGKey(random_seed), 3)
params = model.init(jax.random.PRNGKey(random_seed),graph)

model_state = train_state.TrainState.create(apply_fn=model.apply,
                                            params=params,
                                            tx=optimizer)

# %%
def compute_loss(state, params, graph, labels, one_hot_labels, mask):
  """Computes loss."""
  pred_graph = state.apply_fn(params, graph)
  preds = jax.nn.log_softmax(pred_graph.nodes)
  loss = optax.softmax_cross_entropy(preds, one_hot_labels)
  loss_mask = jnp.sum(jnp.where(mask, loss, 0)) / jnp.sum(mask)

  pred_labels = jnp.argmax(preds, axis=1)
  acc = (pred_labels == labels)
  acc_mask = jnp.sum(jnp.where(mask, acc, 0)) / jnp.sum(mask)
  return loss_mask, acc_mask

# %% [markdown]
# ## Training

# %%
@jax.jit  # Jit the function for efficiency
def train_step(state, graph, graph_labels, one_hot_labels, train_mask):
  # Gradient function
  grad_fn = jax.value_and_grad(compute_loss,  # Function to calculate the loss
                                argnums=1,  # Parameters are second argument of the function
                                has_aux=True  # Function has additional outputs, here accuracy
                              )
  # Determine gradients for current model, parameters and batch
  (loss, acc), grads = grad_fn(state, state.params, graph, graph_labels, one_hot_labels, train_mask)
  # Perform parameter update with gradients and optimizer
  state = state.apply_gradients(grads=grads)
  # Return state and any other value we might want
  return state, loss, acc

# %%
def train_model(state, graph, graph_labels, one_hot_labels, train_mask, val_mask, num_epochs):
  # Training loop
  for epoch in range(num_epochs):
    state, loss, acc = train_step(state, graph, graph_labels, one_hot_labels, train_mask)
    val_loss, val_acc = compute_loss(state, state.params, graph, graph_labels, one_hot_labels, val_mask)
    print(f'step: {epoch:03d}, train loss: {loss:.4f}, train acc: {acc:.4f}, val loss: {val_loss:.4f}, val acc: {val_acc:.4f}')
  return state, acc, val_acc

# %% [markdown]
# ![notes_Page_2.png](data:image/png;base64,...)

# %%
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))
trained_model_state, train_acc, val_acc = train_model(model_state, graph, graph_labels, one_hot_labels, graph_train_mask, graph_val_mask, num_epochs=200)
accuracy_list.append(['Cora', 'train', float(train_acc)])
accuracy_list.append(['Cora', 'valid', float(val_acc)])
# Out:
# step: 000, train loss: 1.9462, train acc: 0.1209, val loss: 1.9386, val acc: 0.3100
# step: 001, train loss: 1.9387, train acc: 0.2972, val loss: 1.9307, val acc: 0.3600
# step: 002, train loss: 1.9309, train acc: 0.3295, val loss: 1.9215, val acc: 0.3720
# step: 003, train loss: 1.9218, train acc: 0.3659, val loss: 1.9113, val acc: 0.3760
# step: 004, train loss: 1.9118, train acc: 0.3651, val loss: 1.9013, val acc: 0.3600
# step: 005, train loss: 1.9020, train acc: 0.3336, val loss: 1.8914, val acc: 0.3280
# step: 006, train loss: 1.8924, train acc: 0.3030, val loss: 1.8811, val acc: 0.3180
# step: 007, train loss: 1.8824, train acc: 0.2914, val loss: 1.8707, val acc: 0.3160
# step: 008, train loss: 1.8723, train acc: 0.2881, val loss: 1.8601, val acc: 0.3160
# step: 009, train loss: 1.8620, train acc: 0.2856, val loss: 1.8494, val acc: 0.3160
# step: 010, train loss: 1.8516, train acc: 0.2848, val loss: 1.8388, val acc: 0.3160
# step: 011, train loss: 1.8411, train acc: 0.2848, val loss: 1.8281, val acc: 0.3160
# step: 012, train loss: 1.8306, train acc: 0.2839, val loss: 1.8175, val acc: 0.3160
# step: 013, train loss: 1.8202, train acc: 0.2839, val loss: 1.8069, val acc: 0.3160
# step: 014, train loss: 1.8096, train acc: 0.2823, val loss: 1.7963, val acc: 0.3160
# step: 015, train loss: 1.7991, train acc: 0.2823, val loss: 1.7858, val acc: 0.3160
# step: 016, train loss: 1.7885, train acc: 0.2823, val loss: 1.7752, val acc: 0.3160
# step: 017, train loss: 1.7777, train acc: 0.2823, val loss: 1.7647, val acc: 0.3160
# step: 018, train loss: 1.7670, train acc: 0.2823, val loss: 1.7543, val acc: 0.3160
# step: 019, train loss: 1.7561, train acc: 0.2823, val loss: 1.7438, val acc: 0.3160
# step: 020, train loss: 1.7451, train acc: 0.2823, val loss: 1.7333, val acc: 0.3160
# step: 021, train loss: 1.7340, train acc: 0.2823, val loss: 1.7228, val acc: 0.3160
# step: 022, train loss: 1.7227, train acc: 0.2831, val loss: 1.7122, val acc: 0.3160
# step: 023, train loss: 1.7113, train acc: 0.2839, val loss: 1.7015, val acc: 0.3180
# step: 024, train loss: 1.6996, train acc: 0.2848, val loss: 1.6907, val acc: 0.3180
# step: 025, train loss: 1.6877, train acc: 0.2873, val loss: 1.6796, val acc: 0.3200
# step: 026, train loss: 1.6754, train acc: 0.2889, val loss: 1.6680, val acc: 0.3220
# step: 027, train loss: 1.6624, train acc: 0.2980, val loss: 1.6557, val acc: 0.3240
# step: 028, train loss: 1.6487, train acc: 0.3071, val loss: 1.6432, val acc: 0.3320
# step: 029, train loss: 1.6345, train acc: 0.3187, val loss: 1.6311, val acc: 0.3460
# step: 030, train loss: 1.6206, train acc: 0.3386, val loss: 1.6193, val acc: 0.3680
# step: 031, train loss: 1.6072, train acc: 0.3626, val loss: 1.6073, val acc: 0.3800
# step: 032, train loss: 1.5936, train acc: 0.3825, val loss: 1.5949, val acc: 0.3940
# step: 033, train loss: 1.5798, train acc: 0.4007, val loss: 1.5822, val acc: 0.4160
# step: 034, train loss: 1.5655, train acc: 0.4172, val loss: 1.5691, val acc: 0.4300
# step: 035, train loss: 1.5510, train acc: 0.4272, val loss: 1.5558, val acc: 0.4440
# step: 036, train loss: 1.5362, train acc: 0.4379, val loss: 1.5422, val acc: 0.4520
# step: 037, train loss: 1.5212, train acc: 0.4586, val loss: 1.5283, val acc: 0.4700
# step: 038, train loss: 1.5060, train acc: 0.4768, val loss: 1.5144, val acc: 0.4940
# step: 039, train loss: 1.4906, train acc: 0.4934, val loss: 1.5003, val acc: 0.5160
# step: 040, train loss: 1.4751, train acc: 0.5149, val loss: 1.4861, val acc: 0.5340
# step: 041, train loss: 1.4594, train acc: 0.5389, val loss: 1.4717, val acc: 0.5460
# step: 042, train loss: 1.4436, train acc: 0.5579, val loss: 1.4573, val acc: 0.5560
# step: 043, train loss: 1.4277, train acc: 0.5745, val loss: 1.4428, val acc: 0.5720
# step: 044, train loss: 1.4116, train acc: 0.5952, val loss: 1.4282, val acc: 0.5880
# step: 045, train loss: 1.3954, train acc: 0.6084, val loss: 1.4136, val acc: 0.6040
# step: 046, train loss: 1.3792, train acc: 0.6258, val loss: 1.3989, val acc: 0.6100
# step: 047, train loss: 1.3628, train acc: 0.6374, val loss: 1.3842, val acc: 0.6160
# step: 048, train loss: 1.3464, train acc: 0.6482, val loss: 1.3695, val acc: 0.6280
# step: 049, train loss: 1.3300, train acc: 0.6573, val loss: 1.3547, val acc: 0.6420
# step: 050, train loss: 1.3135, train acc: 0.6730, val loss: 1.3398, val acc: 0.6500
# step: 051, train loss: 1.2969, train acc: 0.6887, val loss: 1.3249, val acc: 0.6580
# step: 052, train loss: 1.2804, train acc: 0.6970, val loss: 1.3100, val acc: 0.6660
# step: 053, train loss: 1.2638, train acc: 0.7045, val loss: 1.2951, val acc: 0.6640
# step: 054, train loss: 1.2472, train acc: 0.7127, val loss: 1.2801, val acc: 0.6800
# step: 055, train loss: 1.2306, train acc: 0.7260, val loss: 1.2652, val acc: 0.6860
# step: 056, train loss: 1.2140, train acc: 0.7326, val loss: 1.2504, val acc: 0.6980
# step: 057, train loss: 1.1975, train acc: 0.7351, val loss: 1.2355, val acc: 0.7060
# step: 058, train loss: 1.1810, train acc: 0.7425, val loss: 1.2207, val acc: 0.7140
# step: 059, train loss: 1.1645, train acc: 0.7459, val loss: 1.2060, val acc: 0.7160
# step: 060, train loss: 1.1482, train acc: 0.7517, val loss: 1.1913, val acc: 0.7200
# step: 061, train loss: 1.1319, train acc: 0.7583, val loss: 1.1768, val acc: 0.7240
# step: 062, train loss: 1.1157, train acc: 0.7632, val loss: 1.1623, val acc: 0.7360
# step: 063, train loss: 1.0996, train acc: 0.7682, val loss: 1.1480, val acc: 0.7360
# step: 064, train loss: 1.0837, train acc: 0.7707, val loss: 1.1337, val acc: 0.7400
# step: 065, train loss: 1.0678, train acc: 0.7724, val loss: 1.1196, val acc: 0.7400
# step: 066, train loss: 1.0521, train acc: 0.7748, val loss: 1.1056, val acc: 0.7420
# step: 067, train loss: 1.0366, train acc: 0.7781, val loss: 1.0917, val acc: 0.7420
# step: 068, train loss: 1.0212, train acc: 0.7806, val loss: 1.0779, val acc: 0.7420
# step: 069, train loss: 1.0059, train acc: 0.7831, val loss: 1.0643, val acc: 0.7480
# step: 070, train loss: 0.9908, train acc: 0.7848, val loss: 1.0508, val acc: 0.7500
# step: 071, train loss: 0.9759, train acc: 0.7864, val loss: 1.0375, val acc: 0.7500
# step: 072, train loss: 0.9612, train acc: 0.7897, val loss: 1.0244, val acc: 0.7540
# step: 073, train loss: 0.9467, train acc: 0.7914, val loss: 1.0115, val acc: 0.7540
# step: 074, train loss: 0.9323, train acc: 0.7939, val loss: 0.9988, val acc: 0.7580
# step: 075, train loss: 0.9182, train acc: 0.7955, val loss: 0.9862, val acc: 0.7560
# step: 076, train loss: 0.9042, train acc: 0.7988, val loss: 0.9738, val acc: 0.7600
# step: 077, train loss: 0.8905, train acc: 0.8022, val loss: 0.9616, val acc: 0.7620
# step: 078, train loss: 0.8769, train acc: 0.8063, val loss: 0.9496, val acc: 0.7720
# step: 079, train loss: 0.8636, train acc: 0.8079, val loss: 0.9378, val acc: 0.7720
# step: 080, train loss: 0.8505, train acc: 0.8104, val loss: 0.9261, val acc: 0.7720
# step: 081, train loss: 0.8376, train acc: 0.8146, val loss: 0.9147, val acc: 0.7800
# step: 082, train loss: 0.8248, train acc: 0.8220, val loss: 0.9035, val acc: 0.7860
# step: 083, train loss: 0.8123, train acc: 0.8270, val loss: 0.8925, val acc: 0.7940
# step: 084, train loss: 0.8000, train acc: 0.8328, val loss: 0.8816, val acc: 0.7960
# step: 085, train loss: 0.7879, train acc: 0.8369, val loss: 0.8710, val acc: 0.7980
# step: 086, train loss: 0.7760, train acc: 0.8386, val loss: 0.8605, val acc: 0.8000
# step: 087, train loss: 0.7643, train acc: 0.8444, val loss: 0.8503, val acc: 0.8020
# step: 088, train loss: 0.7529, train acc: 0.8502, val loss: 0.8402, val acc: 0.8100
# step: 089, train loss: 0.7416, train acc: 0.8526, val loss: 0.8303, val acc: 0.8120
# step: 090, train loss: 0.7305, train acc: 0.8601, val loss: 0.8207, val acc: 0.8160
# step: 091, train loss: 0.7196, train acc: 0.8642, val loss: 0.8112, val acc: 0.8180
# step: 092, train loss: 0.7089, train acc: 0.8675, val loss: 0.8019, val acc: 0.8180
# step: 093, train loss: 0.6984, train acc: 0.8692, val loss: 0.7928, val acc: 0.8180
# step: 094, train loss: 0.6880, train acc: 0.8733, val loss: 0.7839, val acc: 0.8200
# step: 095, train loss: 0.6779, train acc: 0.8750, val loss: 0.7752, val acc: 0.8220
# step: 096, train loss: 0.6680, train acc: 0.8800, val loss: 0.7667, val acc: 0.8280
# step: 097, train loss: 0.6582, train acc: 0.8833, val loss: 0.7584, val acc: 0.8320
# step: 098, train loss: 0.6486, train acc: 0.8849, val loss: 0.7502, val acc: 0.8320
# step: 099, train loss: 0.6392, train acc: 0.8882, val loss: 0.7423, val acc: 0.8380
# step: 100, train loss: 0.6300, train acc: 0.8899, val loss: 0.7345, val acc: 0.8380
# step: 101, train loss: 0.6210, train acc: 0.8932, val loss: 0.7269, val acc: 0.8400
# step: 102, train loss: 0.6121, train acc: 0.8949, val loss: 0.7195, val acc: 0.8420
# step: 103, train loss: 0.6034, train acc: 0.8965, val loss: 0.7122, val acc: 0.8420
# step: 104, train loss: 0.5948, train acc: 0.8965, val loss: 0.7051, val acc: 0.8440
# step: 105, train loss: 0.5864, train acc: 0.8982, val loss: 0.6982, val acc: 0.8420
# step: 106, train loss: 0.5782, train acc: 0.8982, val loss: 0.6915, val acc: 0.8460
# step: 107, train loss: 0.5702, train acc: 0.8998, val loss: 0.6849, val acc: 0.8460
# step: 108, train loss: 0.5622, train acc: 0.8998, val loss: 0.6785, val acc: 0.8460
# step: 109, train loss: 0.5545, train acc: 0.8998, val loss: 0.6722, val acc: 0.8480
# step: 110, train loss: 0.5469, train acc: 0.9015, val loss: 0.6661, val acc: 0.8500
# step: 111, train loss: 0.5394, train acc: 0.9015, val loss: 0.6601, val acc: 0.8540
# step: 112, train loss: 0.5321, train acc: 0.9023, val loss: 0.6543, val acc: 0.8540
# step: 113, train loss: 0.5249, train acc: 0.9056, val loss: 0.6486, val acc: 0.8560
# step: 114, train loss: 0.5179, train acc: 0.9065, val loss: 0.6430, val acc: 0.8560
# step: 115, train loss: 0.5110, train acc: 0.9081, val loss: 0.6376, val acc: 0.8580
# step: 116, train loss: 0.5043, train acc: 0.9073, val loss: 0.6322, val acc: 0.8600
# step: 117, train loss: 0.4977, train acc: 0.9073, val loss: 0.6271, val acc: 0.8600
# step: 118, train loss: 0.4912, train acc: 0.9073, val loss: 0.6220, val acc: 0.8620
# step: 119, train loss: 0.4848, train acc: 0.9098, val loss: 0.6171, val acc: 0.8620
# step: 120, train loss: 0.4786, train acc: 0.9131, val loss: 0.6123, val acc: 0.8640
# step: 121, train loss: 0.4724, train acc: 0.9156, val loss: 0.6077, val acc: 0.8640
# step: 122, train loss: 0.4665, train acc: 0.9164, val loss: 0.6031, val acc: 0.8640
# step: 123, train loss: 0.4606, train acc: 0.9164, val loss: 0.5987, val acc: 0.8640
# step: 124, train loss: 0.4548, train acc: 0.9164, val loss: 0.5944, val acc: 0.8660
# step: 125, train loss: 0.4492, train acc: 0.9180, val loss: 0.5902, val acc: 0.8640
# step: 126, train loss: 0.4436, train acc: 0.9172, val loss: 0.5861, val acc: 0.8640
# step: 127, train loss: 0.4382, train acc: 0.9172, val loss: 0.5821, val acc: 0.8640
# step: 128, train loss: 0.4329, train acc: 0.9180, val loss: 0.5782, val acc: 0.8620
# step: 129, train loss: 0.4277, train acc: 0.9180, val loss: 0.5744, val acc: 0.8620
# step: 130, train loss: 0.4226, train acc: 0.9197, val loss: 0.5708, val acc: 0.8620
# step: 131, train loss: 0.4176, train acc: 0.9214, val loss: 0.5672, val acc: 0.8600
# step: 132, train loss: 0.4126, train acc: 0.9214, val loss: 0.5637, val acc: 0.8620
# step: 133, train loss: 0.4078, train acc: 0.9214, val loss: 0.5603, val acc: 0.8640
# step: 134, train loss: 0.4031, train acc: 0.9247, val loss: 0.5570, val acc: 0.8640
# step: 135, train loss: 0.3985, train acc: 0.9255, val loss: 0.5538, val acc: 0.8620
# step: 136, train loss: 0.3939, train acc: 0.9263, val loss: 0.5507, val acc: 0.8620
# step: 137, train loss: 0.3895, train acc: 0.9272, val loss: 0.5477, val acc: 0.8620
# step: 138, train loss: 0.3851, train acc: 0.9272, val loss: 0.5447, val acc: 0.8620
# step: 139, train loss: 0.3808, train acc: 0.9280, val loss: 0.5419, val acc: 0.8620
# step: 140, train loss: 0.3766, train acc: 0.9280, val loss: 0.5391, val acc: 0.8600
# step: 141, train loss: 0.3725, train acc: 0.9288, val loss: 0.5364, val acc: 0.8600
# step: 142, train loss: 0.3684, train acc: 0.9288, val loss: 0.5337, val acc: 0.8600
# step: 143, train loss: 0.3645, train acc: 0.9288, val loss: 0.5312, val acc: 0.8620
# step: 144, train loss: 0.3606, train acc: 0.9288, val loss: 0.5287, val acc: 0.8600
# step: 145, train loss: 0.3567, train acc: 0.9288, val loss: 0.5263, val acc: 0.8600
# step: 146, train loss: 0.3530, train acc: 0.9288, val loss: 0.5239, val acc: 0.8600
# step: 147, train loss: 0.3493, train acc: 0.9280, val loss: 0.5216, val acc: 0.8600
# step: 148, train loss: 0.3457, train acc: 0.9288, val loss: 0.5194, val acc: 0.8600
# step: 149, train loss: 0.3421, train acc: 0.9288, val loss: 0.5172, val acc: 0.8600
# step: 150, train loss: 0.3387, train acc: 0.9296, val loss: 0.5151, val acc: 0.8600
# step: 151, train loss: 0.3352, train acc: 0.9313, val loss: 0.5131, val acc: 0.8600
# step: 152, train loss: 0.3319, train acc: 0.9313, val loss: 0.5111, val acc: 0.8600
# step: 153, train loss: 0.3286, train acc: 0.9313, val loss: 0.5092, val acc: 0.8600
# step: 154, train loss: 0.3253, train acc: 0.9329, val loss: 0.5073, val acc: 0.8600
# step: 155, train loss: 0.3222, train acc: 0.9329, val loss: 0.5055, val acc: 0.8600
# step: 156, train loss: 0.3190, train acc: 0.9346, val loss: 0.5037, val acc: 0.8600
# step: 157, train loss: 0.3160, train acc: 0.9346, val loss: 0.5020, val acc: 0.8600
# step: 158, train loss: 0.3130, train acc: 0.9363, val loss: 0.5004, val acc: 0.8600
# step: 159, train loss: 0.3100, train acc: 0.9363, val loss: 0.4988, val acc: 0.8600
# step: 160, train loss: 0.3071, train acc: 0.9379, val loss: 0.4972, val acc: 0.8600
# step: 161, train loss: 0.3042, train acc: 0.9379, val loss: 0.4957, val acc: 0.8580
# step: 162, train loss: 0.3014, train acc: 0.9379, val loss: 0.4942, val acc: 0.8580
# step: 163, train loss: 0.2986, train acc: 0.9379, val loss: 0.4928, val acc: 0.8560
# step: 164, train loss: 0.2959, train acc: 0.9396, val loss: 0.4914, val acc: 0.8560
# step: 165, train loss: 0.2932, train acc: 0.9396, val loss: 0.4901, val acc: 0.8560
# step: 166, train loss: 0.2906, train acc: 0.9396, val loss: 0.4887, val acc: 0.8560
# step: 167, train loss: 0.2880, train acc: 0.9396, val loss: 0.4875, val acc: 0.8560
# step: 168, train loss: 0.2855, train acc: 0.9404, val loss: 0.4863, val acc: 0.8560
# step: 169, train loss: 0.2830, train acc: 0.9404, val loss: 0.4851, val acc: 0.8560
# step: 170, train loss: 0.2805, train acc: 0.9404, val loss: 0.4839, val acc: 0.8560
# step: 171, train loss: 0.2781, train acc: 0.9404, val loss: 0.4828, val acc: 0.8560
# step: 172, train loss: 0.2757, train acc: 0.9412, val loss: 0.4818, val acc: 0.8560
# step: 173, train loss: 0.2734, train acc: 0.9429, val loss: 0.4807, val acc: 0.8560
# step: 174, train loss: 0.2710, train acc: 0.9437, val loss: 0.4797, val acc: 0.8540
# step: 175, train loss: 0.2688, train acc: 0.9445, val loss: 0.4787, val acc: 0.8540
# step: 176, train loss: 0.2665, train acc: 0.9445, val loss: 0.4778, val acc: 0.8520
# step: 177, train loss: 0.2643, train acc: 0.9445, val loss: 0.4769, val acc: 0.8500
# step: 178, train loss: 0.2621, train acc: 0.9445, val loss: 0.4760, val acc: 0.8500
# step: 179, train loss: 0.2600, train acc: 0.9445, val loss: 0.4752, val acc: 0.8500
# step: 180, train loss: 0.2579, train acc: 0.9445, val loss: 0.4744, val acc: 0.8520
# step: 181, train loss: 0.2558, train acc: 0.9445, val loss: 0.4736, val acc: 0.8520
# step: 182, train loss: 0.2538, train acc: 0.9445, val loss: 0.4728, val acc: 0.8520
# step: 183, train loss: 0.2518, train acc: 0.9454, val loss: 0.4721, val acc: 0.8520
# step: 184, train loss: 0.2498, train acc: 0.9462, val loss: 0.4714, val acc: 0.8540
# step: 185, train loss: 0.2478, train acc: 0.9462, val loss: 0.4707, val acc: 0.8540
# step: 186, train loss: 0.2459, train acc: 0.9462, val loss: 0.4700, val acc: 0.8540
# step: 187, train loss: 0.2440, train acc: 0.9470, val loss: 0.4694, val acc: 0.8540
# step: 188, train loss: 0.2421, train acc: 0.9470, val loss: 0.4687, val acc: 0.8540
# step: 189, train loss: 0.2403, train acc: 0.9470, val loss: 0.4681, val acc: 0.8540
# step: 190, train loss: 0.2385, train acc: 0.9478, val loss: 0.4676, val acc: 0.8540
# step: 191, train loss: 0.2367, train acc: 0.9487, val loss: 0.4670, val acc: 0.8560
# step: 192, train loss: 0.2349, train acc: 0.9495, val loss: 0.4665, val acc: 0.8540
# step: 193, train loss: 0.2332, train acc: 0.9503, val loss: 0.4660, val acc: 0.8540
# step: 194, train loss: 0.2315, train acc: 0.9503, val loss: 0.4655, val acc: 0.8540
# step: 195, train loss: 0.2298, train acc: 0.9512, val loss: 0.4650, val acc: 0.8540
# step: 196, train loss: 0.2281, train acc: 0.9512, val loss: 0.4646, val acc: 0.8540
# step: 197, train loss: 0.2264, train acc: 0.9520, val loss: 0.4641, val acc: 0.8540
# step: 198, train loss: 0.2248, train acc: 0.9520, val loss: 0.4637, val acc: 0.8540
# step: 199, train loss: 0.2232, train acc: 0.9520, val loss: 0.4633, val acc: 0.8540

# %% [markdown]
# ## Testing

# %%
test_loss, test_acc = compute_loss(trained_model_state, trained_model_state.params, graph, graph_labels, one_hot_labels, graph_test_mask)
print(f'test loss: {test_loss:.4f}, test acc: {test_acc:.4f}')
accuracy_list.append(['Cora', 'test', float(test_acc)])
# Out:
# test loss: 0.4664, test acc: 0.8550

# %% [markdown]
# ## Visualizing nodes before and after training

# %%
nodes_untrained = model_state.apply_fn(model_state.params, graph).nodes
z_nodes_untrained = TSNE(n_components=2).fit_transform(nodes_untrained)

nodes_trained = trained_model_state.apply_fn(trained_model_state.params, graph).nodes
z_nodes_trained = TSNE(n_components=2).fit_transform(nodes_trained)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].set_title('Before training')
axs[0].scatter(z_nodes_untrained[:,0], z_nodes_untrained[:,1], marker='o', color=np.array(plot_colors)[graph_labels])

axs[1].set_title('After training')
axs[1].scatter(z_nodes_trained[:,0], z_nodes_trained[:,1], marker='o', color=np.array(plot_colors)[graph_labels])

for ax in axs:
  ax.tick_params(axis='both',which='both',bottom=False,top=False,left=False,right=False,
            labelbottom=False,labeltop=False,labelleft=False,labelright=False);
  ax.set(xlabel=None, ylabel=None)
plt.show()

# %% [markdown]
# ## Import CiteSeer Dataset
# You can find a description of this dataset in [Pytorch-Geometric documentation](https://pytorch-geometric.readthedocs.io/en/latest/generated/torch_geometric.datasets.Planetoid.html#torch_geometric.datasets.Planetoid). In case of `split='full'`, all nodes except those in the validation and test sets will be used for training.

# %%
dataset = Planetoid(root='data/Planetoid', name='CiteSeer', split='full', transform=NormalizeFeatures())
num_features = dataset.num_features
num_classes = dataset.num_classes
data_CiteSeer = dataset[0]  # Get the first graph object.
data_CiteSeer
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.test.index
# Processing...
# Done!
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])

# %%
graph = jraph.GraphsTuple(
      n_node=jnp.asarray([data_CiteSeer.x.shape[0]]),
      n_edge=jnp.asarray([data_CiteSeer.edge_index.shape[1]]),
      nodes=jnp.asarray(data_CiteSeer.x),
      # No edge features.
      edges=None,
      globals=None,
      senders=jnp.asarray([data_CiteSeer.edge_index[0,:]]).squeeze(),
      receivers=jnp.asarray([data_CiteSeer.edge_index[1,:]]).squeeze())

graph_train_mask = jnp.asarray([data_CiteSeer.train_mask]).squeeze()
graph_val_mask = jnp.asarray([data_CiteSeer.val_mask]).squeeze()
graph_test_mask = jnp.asarray([data_CiteSeer.test_mask]).squeeze()
graph_labels = jnp.asarray([data_CiteSeer.y]).squeeze()
one_hot_labels = jax.nn.one_hot(graph_labels, len(jnp.unique(graph_labels)))

# %%
model = GCN(8, len(jnp.unique(graph_labels)))
model
# Out:
# GCN(
#     # attributes
#     gcn1_output_dim = 8
#     output_dim = 6
# )

# %%
optimizer = optax.adam(learning_rate=0.01)

rng, inp_rng, init_rng = jax.random.split(jax.random.PRNGKey(random_seed), 3)
params = model.init(jax.random.PRNGKey(random_seed),graph)

model_state = train_state.TrainState.create(apply_fn=model.apply,
                                            params=params,
                                            tx=optimizer)

# %%
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))
trained_model_state, train_acc, val_acc = train_model(model_state, graph, graph_labels, one_hot_labels, graph_train_mask, graph_val_mask, num_epochs=200)
accuracy_list.append(['CiteSeer', 'train', float(train_acc)])
accuracy_list.append(['CiteSeer', 'valid', float(val_acc)])
# Out:
# step: 000, train loss: 1.7918, train acc: 0.1932, val loss: 1.7849, val acc: 0.2080
# step: 001, train loss: 1.7857, train acc: 0.1970, val loss: 1.7781, val acc: 0.2080
# step: 002, train loss: 1.7796, train acc: 0.1970, val loss: 1.7709, val acc: 0.2080
# step: 003, train loss: 1.7730, train acc: 0.1970, val loss: 1.7628, val acc: 0.2100
# step: 004, train loss: 1.7654, train acc: 0.1987, val loss: 1.7548, val acc: 0.2160
# step: 005, train loss: 1.7579, train acc: 0.2053, val loss: 1.7472, val acc: 0.2200
# step: 006, train loss: 1.7507, train acc: 0.2080, val loss: 1.7400, val acc: 0.2180
# step: 007, train loss: 1.7439, train acc: 0.2063, val loss: 1.7328, val acc: 0.2180
# step: 008, train loss: 1.7370, train acc: 0.2063, val loss: 1.7255, val acc: 0.2180
# step: 009, train loss: 1.7300, train acc: 0.2091, val loss: 1.7182, val acc: 0.2240
# step: 010, train loss: 1.7230, train acc: 0.2195, val loss: 1.7109, val acc: 0.2420
# step: 011, train loss: 1.7159, train acc: 0.2463, val loss: 1.7036, val acc: 0.2720
# step: 012, train loss: 1.7086, train acc: 0.2742, val loss: 1.6962, val acc: 0.2980
# step: 013, train loss: 1.7013, train acc: 0.2999, val loss: 1.6888, val acc: 0.3260
# step: 014, train loss: 1.6940, train acc: 0.3246, val loss: 1.6815, val acc: 0.3340
# step: 015, train loss: 1.6865, train acc: 0.3383, val loss: 1.6740, val acc: 0.3600
# step: 016, train loss: 1.6788, train acc: 0.3492, val loss: 1.6665, val acc: 0.3760
# step: 017, train loss: 1.6710, train acc: 0.3591, val loss: 1.6588, val acc: 0.3780
# step: 018, train loss: 1.6629, train acc: 0.3815, val loss: 1.6509, val acc: 0.4020
# step: 019, train loss: 1.6545, train acc: 0.4143, val loss: 1.6428, val acc: 0.4360
# step: 020, train loss: 1.6457, train acc: 0.4516, val loss: 1.6346, val acc: 0.4900
# step: 021, train loss: 1.6367, train acc: 0.4959, val loss: 1.6261, val acc: 0.5100
# step: 022, train loss: 1.6273, train acc: 0.5364, val loss: 1.6174, val acc: 0.5680
# step: 023, train loss: 1.6176, train acc: 0.5703, val loss: 1.6086, val acc: 0.6040
# step: 024, train loss: 1.6077, train acc: 0.5939, val loss: 1.5995, val acc: 0.6300
# step: 025, train loss: 1.5974, train acc: 0.6119, val loss: 1.5903, val acc: 0.6440
# step: 026, train loss: 1.5869, train acc: 0.6223, val loss: 1.5809, val acc: 0.6680
# step: 027, train loss: 1.5762, train acc: 0.6322, val loss: 1.5713, val acc: 0.6660
# step: 028, train loss: 1.5652, train acc: 0.6316, val loss: 1.5616, val acc: 0.6660
# step: 029, train loss: 1.5540, train acc: 0.6300, val loss: 1.5516, val acc: 0.6740
# step: 030, train loss: 1.5427, train acc: 0.6355, val loss: 1.5414, val acc: 0.6720
# step: 031, train loss: 1.5311, train acc: 0.6393, val loss: 1.5309, val acc: 0.6760
# step: 032, train loss: 1.5192, train acc: 0.6415, val loss: 1.5202, val acc: 0.6780
# step: 033, train loss: 1.5071, train acc: 0.6453, val loss: 1.5091, val acc: 0.6780
# step: 034, train loss: 1.4947, train acc: 0.6475, val loss: 1.4977, val acc: 0.6760
# step: 035, train loss: 1.4820, train acc: 0.6497, val loss: 1.4862, val acc: 0.6780
# step: 036, train loss: 1.4692, train acc: 0.6530, val loss: 1.4744, val acc: 0.6780
# step: 037, train loss: 1.4561, train acc: 0.6541, val loss: 1.4625, val acc: 0.6800
# step: 038, train loss: 1.4430, train acc: 0.6530, val loss: 1.4504, val acc: 0.6820
# step: 039, train loss: 1.4296, train acc: 0.6568, val loss: 1.4383, val acc: 0.6820
# step: 040, train loss: 1.4162, train acc: 0.6617, val loss: 1.4260, val acc: 0.6840
# step: 041, train loss: 1.4027, train acc: 0.6650, val loss: 1.4137, val acc: 0.6860
# step: 042, train loss: 1.3890, train acc: 0.6678, val loss: 1.4013, val acc: 0.6900
# step: 043, train loss: 1.3751, train acc: 0.6738, val loss: 1.3888, val acc: 0.7020
# step: 044, train loss: 1.3611, train acc: 0.6804, val loss: 1.3763, val acc: 0.7100
# step: 045, train loss: 1.3469, train acc: 0.6853, val loss: 1.3637, val acc: 0.7160
# step: 046, train loss: 1.3327, train acc: 0.6913, val loss: 1.3510, val acc: 0.7220
# step: 047, train loss: 1.3184, train acc: 0.6979, val loss: 1.3384, val acc: 0.7280
# step: 048, train loss: 1.3040, train acc: 0.7088, val loss: 1.3257, val acc: 0.7360
# step: 049, train loss: 1.2895, train acc: 0.7159, val loss: 1.3131, val acc: 0.7400
# step: 050, train loss: 1.2751, train acc: 0.7192, val loss: 1.3004, val acc: 0.7480
# step: 051, train loss: 1.2607, train acc: 0.7241, val loss: 1.2877, val acc: 0.7520
# step: 052, train loss: 1.2462, train acc: 0.7280, val loss: 1.2751, val acc: 0.7540
# step: 053, train loss: 1.2318, train acc: 0.7313, val loss: 1.2624, val acc: 0.7540
# step: 054, train loss: 1.2173, train acc: 0.7329, val loss: 1.2498, val acc: 0.7540
# step: 055, train loss: 1.2029, train acc: 0.7362, val loss: 1.2372, val acc: 0.7580
# step: 056, train loss: 1.1885, train acc: 0.7373, val loss: 1.2246, val acc: 0.7660
# step: 057, train loss: 1.1742, train acc: 0.7384, val loss: 1.2122, val acc: 0.7680
# step: 058, train loss: 1.1600, train acc: 0.7389, val loss: 1.1999, val acc: 0.7680
# step: 059, train loss: 1.1459, train acc: 0.7406, val loss: 1.1878, val acc: 0.7680
# step: 060, train loss: 1.1319, train acc: 0.7422, val loss: 1.1758, val acc: 0.7680
# step: 061, train loss: 1.1180, train acc: 0.7427, val loss: 1.1640, val acc: 0.7700
# step: 062, train loss: 1.1042, train acc: 0.7438, val loss: 1.1524, val acc: 0.7720
# step: 063, train loss: 1.0905, train acc: 0.7449, val loss: 1.1410, val acc: 0.7720
# step: 064, train loss: 1.0770, train acc: 0.7477, val loss: 1.1298, val acc: 0.7720
# step: 065, train loss: 1.0636, train acc: 0.7488, val loss: 1.1188, val acc: 0.7720
# step: 066, train loss: 1.0504, train acc: 0.7510, val loss: 1.1079, val acc: 0.7740
# step: 067, train loss: 1.0374, train acc: 0.7515, val loss: 1.0973, val acc: 0.7760
# step: 068, train loss: 1.0245, train acc: 0.7521, val loss: 1.0868, val acc: 0.7760
# step: 069, train loss: 1.0118, train acc: 0.7548, val loss: 1.0764, val acc: 0.7760
# step: 070, train loss: 0.9993, train acc: 0.7548, val loss: 1.0662, val acc: 0.7760
# step: 071, train loss: 0.9869, train acc: 0.7559, val loss: 1.0562, val acc: 0.7760
# step: 072, train loss: 0.9748, train acc: 0.7570, val loss: 1.0464, val acc: 0.7780
# step: 073, train loss: 0.9628, train acc: 0.7581, val loss: 1.0368, val acc: 0.7780
# step: 074, train loss: 0.9510, train acc: 0.7619, val loss: 1.0275, val acc: 0.7780
# step: 075, train loss: 0.9395, train acc: 0.7630, val loss: 1.0183, val acc: 0.7760
# step: 076, train loss: 0.9281, train acc: 0.7646, val loss: 1.0094, val acc: 0.7760
# step: 077, train loss: 0.9169, train acc: 0.7657, val loss: 1.0007, val acc: 0.7780
# step: 078, train loss: 0.9059, train acc: 0.7668, val loss: 0.9922, val acc: 0.7800
# step: 079, train loss: 0.8952, train acc: 0.7690, val loss: 0.9840, val acc: 0.7800
# step: 080, train loss: 0.8846, train acc: 0.7712, val loss: 0.9759, val acc: 0.7820
# step: 081, train loss: 0.8742, train acc: 0.7723, val loss: 0.9681, val acc: 0.7820
# step: 082, train loss: 0.8640, train acc: 0.7739, val loss: 0.9605, val acc: 0.7800
# step: 083, train loss: 0.8540, train acc: 0.7750, val loss: 0.9530, val acc: 0.7860
# step: 084, train loss: 0.8442, train acc: 0.7761, val loss: 0.9458, val acc: 0.7900
# step: 085, train loss: 0.8345, train acc: 0.7783, val loss: 0.9387, val acc: 0.7920
# step: 086, train loss: 0.8251, train acc: 0.7794, val loss: 0.9318, val acc: 0.7920
# step: 087, train loss: 0.8159, train acc: 0.7805, val loss: 0.9251, val acc: 0.7920
# step: 088, train loss: 0.8068, train acc: 0.7827, val loss: 0.9186, val acc: 0.7900
# step: 089, train loss: 0.7979, train acc: 0.7843, val loss: 0.9123, val acc: 0.7920
# step: 090, train loss: 0.7892, train acc: 0.7860, val loss: 0.9062, val acc: 0.7960
# step: 091, train loss: 0.7806, train acc: 0.7887, val loss: 0.9003, val acc: 0.7960
# step: 092, train loss: 0.7723, train acc: 0.7898, val loss: 0.8946, val acc: 0.7960
# step: 093, train loss: 0.7641, train acc: 0.7926, val loss: 0.8890, val acc: 0.7960
# step: 094, train loss: 0.7560, train acc: 0.7926, val loss: 0.8837, val acc: 0.7960
# step: 095, train loss: 0.7482, train acc: 0.7926, val loss: 0.8785, val acc: 0.7940
# step: 096, train loss: 0.7405, train acc: 0.7947, val loss: 0.8735, val acc: 0.7920
# step: 097, train loss: 0.7329, train acc: 0.7953, val loss: 0.8686, val acc: 0.7900
# step: 098, train loss: 0.7255, train acc: 0.7986, val loss: 0.8639, val acc: 0.7900
# step: 099, train loss: 0.7182, train acc: 0.7997, val loss: 0.8594, val acc: 0.7920
# step: 100, train loss: 0.7111, train acc: 0.8002, val loss: 0.8550, val acc: 0.7940
# step: 101, train loss: 0.7041, train acc: 0.8035, val loss: 0.8508, val acc: 0.7960
# step: 102, train loss: 0.6973, train acc: 0.8062, val loss: 0.8468, val acc: 0.7960
# step: 103, train loss: 0.6906, train acc: 0.8073, val loss: 0.8428, val acc: 0.7980
# step: 104, train loss: 0.6840, train acc: 0.8084, val loss: 0.8391, val acc: 0.7940
# step: 105, train loss: 0.6776, train acc: 0.8112, val loss: 0.8355, val acc: 0.7940
# step: 106, train loss: 0.6713, train acc: 0.8128, val loss: 0.8320, val acc: 0.7920
# step: 107, train loss: 0.6651, train acc: 0.8144, val loss: 0.8286, val acc: 0.7920
# step: 108, train loss: 0.6590, train acc: 0.8144, val loss: 0.8254, val acc: 0.7920
# step: 109, train loss: 0.6531, train acc: 0.8155, val loss: 0.8223, val acc: 0.7860
# step: 110, train loss: 0.6472, train acc: 0.8161, val loss: 0.8194, val acc: 0.7860
# step: 111, train loss: 0.6415, train acc: 0.8166, val loss: 0.8165, val acc: 0.7860
# step: 112, train loss: 0.6359, train acc: 0.8177, val loss: 0.8138, val acc: 0.7860
# step: 113, train loss: 0.6303, train acc: 0.8183, val loss: 0.8112, val acc: 0.7860
# step: 114, train loss: 0.6249, train acc: 0.8188, val loss: 0.8087, val acc: 0.7860
# step: 115, train loss: 0.6196, train acc: 0.8199, val loss: 0.8063, val acc: 0.7880
# step: 116, train loss: 0.6144, train acc: 0.8210, val loss: 0.8040, val acc: 0.7860
# step: 117, train loss: 0.6093, train acc: 0.8216, val loss: 0.8019, val acc: 0.7900
# step: 118, train loss: 0.6042, train acc: 0.8216, val loss: 0.7998, val acc: 0.7900
# step: 119, train loss: 0.5993, train acc: 0.8221, val loss: 0.7978, val acc: 0.7900
# step: 120, train loss: 0.5944, train acc: 0.8232, val loss: 0.7959, val acc: 0.7920
# step: 121, train loss: 0.5897, train acc: 0.8238, val loss: 0.7941, val acc: 0.7920
# step: 122, train loss: 0.5850, train acc: 0.8254, val loss: 0.7924, val acc: 0.7880
# step: 123, train loss: 0.5804, train acc: 0.8259, val loss: 0.7907, val acc: 0.7880
# step: 124, train loss: 0.5758, train acc: 0.8270, val loss: 0.7892, val acc: 0.7880
# step: 125, train loss: 0.5714, train acc: 0.8276, val loss: 0.7878, val acc: 0.7880
# step: 126, train loss: 0.5670, train acc: 0.8276, val loss: 0.7864, val acc: 0.7880
# step: 127, train loss: 0.5627, train acc: 0.8281, val loss: 0.7851, val acc: 0.7880
# step: 128, train loss: 0.5585, train acc: 0.8281, val loss: 0.7838, val acc: 0.7880
# step: 129, train loss: 0.5543, train acc: 0.8287, val loss: 0.7827, val acc: 0.7860
# step: 130, train loss: 0.5503, train acc: 0.8298, val loss: 0.7816, val acc: 0.7860
# step: 131, train loss: 0.5462, train acc: 0.8298, val loss: 0.7806, val acc: 0.7880
# step: 132, train loss: 0.5423, train acc: 0.8309, val loss: 0.7796, val acc: 0.7880
# step: 133, train loss: 0.5384, train acc: 0.8309, val loss: 0.7788, val acc: 0.7860
# step: 134, train loss: 0.5345, train acc: 0.8325, val loss: 0.7780, val acc: 0.7840
# step: 135, train loss: 0.5308, train acc: 0.8325, val loss: 0.7773, val acc: 0.7840
# step: 136, train loss: 0.5271, train acc: 0.8331, val loss: 0.7766, val acc: 0.7840
# step: 137, train loss: 0.5234, train acc: 0.8358, val loss: 0.7760, val acc: 0.7840
# step: 138, train loss: 0.5198, train acc: 0.8358, val loss: 0.7754, val acc: 0.7840
# step: 139, train loss: 0.5162, train acc: 0.8363, val loss: 0.7749, val acc: 0.7840
# step: 140, train loss: 0.5128, train acc: 0.8380, val loss: 0.7745, val acc: 0.7820
# step: 141, train loss: 0.5093, train acc: 0.8385, val loss: 0.7741, val acc: 0.7800
# step: 142, train loss: 0.5059, train acc: 0.8385, val loss: 0.7738, val acc: 0.7820
# step: 143, train loss: 0.5026, train acc: 0.8391, val loss: 0.7735, val acc: 0.7780
# step: 144, train loss: 0.4993, train acc: 0.8402, val loss: 0.7732, val acc: 0.7780
# step: 145, train loss: 0.4960, train acc: 0.8424, val loss: 0.7730, val acc: 0.7780
# step: 146, train loss: 0.4928, train acc: 0.8435, val loss: 0.7729, val acc: 0.7800
# step: 147, train loss: 0.4897, train acc: 0.8456, val loss: 0.7728, val acc: 0.7800
# step: 148, train loss: 0.4866, train acc: 0.8456, val loss: 0.7727, val acc: 0.7800
# step: 149, train loss: 0.4835, train acc: 0.8462, val loss: 0.7727, val acc: 0.7780
# step: 150, train loss: 0.4805, train acc: 0.8462, val loss: 0.7727, val acc: 0.7800
# step: 151, train loss: 0.4775, train acc: 0.8478, val loss: 0.7728, val acc: 0.7800
# step: 152, train loss: 0.4746, train acc: 0.8478, val loss: 0.7729, val acc: 0.7800
# step: 153, train loss: 0.4717, train acc: 0.8478, val loss: 0.7731, val acc: 0.7800
# step: 154, train loss: 0.4688, train acc: 0.8484, val loss: 0.7733, val acc: 0.7800
# step: 155, train loss: 0.4660, train acc: 0.8489, val loss: 0.7735, val acc: 0.7740
# step: 156, train loss: 0.4632, train acc: 0.8495, val loss: 0.7738, val acc: 0.7740
# step: 157, train loss: 0.4605, train acc: 0.8511, val loss: 0.7741, val acc: 0.7720
# step: 158, train loss: 0.4577, train acc: 0.8522, val loss: 0.7744, val acc: 0.7680
# step: 159, train loss: 0.4551, train acc: 0.8522, val loss: 0.7748, val acc: 0.7680
# step: 160, train loss: 0.4524, train acc: 0.8539, val loss: 0.7752, val acc: 0.7680
# step: 161, train loss: 0.4498, train acc: 0.8555, val loss: 0.7756, val acc: 0.7660
# step: 162, train loss: 0.4472, train acc: 0.8560, val loss: 0.7761, val acc: 0.7620
# step: 163, train loss: 0.4447, train acc: 0.8566, val loss: 0.7766, val acc: 0.7620
# step: 164, train loss: 0.4422, train acc: 0.8577, val loss: 0.7771, val acc: 0.7620
# step: 165, train loss: 0.4397, train acc: 0.8577, val loss: 0.7776, val acc: 0.7640
# step: 166, train loss: 0.4373, train acc: 0.8582, val loss: 0.7782, val acc: 0.7640
# step: 167, train loss: 0.4348, train acc: 0.8582, val loss: 0.7788, val acc: 0.7640
# step: 168, train loss: 0.4324, train acc: 0.8582, val loss: 0.7794, val acc: 0.7640
# step: 169, train loss: 0.4301, train acc: 0.8582, val loss: 0.7801, val acc: 0.7640
# step: 170, train loss: 0.4277, train acc: 0.8582, val loss: 0.7808, val acc: 0.7640
# step: 171, train loss: 0.4254, train acc: 0.8582, val loss: 0.7815, val acc: 0.7640
# step: 172, train loss: 0.4232, train acc: 0.8582, val loss: 0.7822, val acc: 0.7640
# step: 173, train loss: 0.4209, train acc: 0.8593, val loss: 0.7829, val acc: 0.7620
# step: 174, train loss: 0.4187, train acc: 0.8593, val loss: 0.7837, val acc: 0.7620
# step: 175, train loss: 0.4165, train acc: 0.8599, val loss: 0.7845, val acc: 0.7620
# step: 176, train loss: 0.4143, train acc: 0.8604, val loss: 0.7853, val acc: 0.7620
# step: 177, train loss: 0.4122, train acc: 0.8604, val loss: 0.7861, val acc: 0.7620
# step: 178, train loss: 0.4100, train acc: 0.8610, val loss: 0.7870, val acc: 0.7620
# step: 179, train loss: 0.4080, train acc: 0.8615, val loss: 0.7879, val acc: 0.7620
# step: 180, train loss: 0.4059, train acc: 0.8615, val loss: 0.7887, val acc: 0.7600
# step: 181, train loss: 0.4038, train acc: 0.8626, val loss: 0.7897, val acc: 0.7580
# step: 182, train loss: 0.4018, train acc: 0.8626, val loss: 0.7906, val acc: 0.7560
# step: 183, train loss: 0.3998, train acc: 0.8626, val loss: 0.7915, val acc: 0.7580
# step: 184, train loss: 0.3978, train acc: 0.8632, val loss: 0.7925, val acc: 0.7580
# step: 185, train loss: 0.3958, train acc: 0.8637, val loss: 0.7935, val acc: 0.7580
# step: 186, train loss: 0.3939, train acc: 0.8648, val loss: 0.7944, val acc: 0.7580
# step: 187, train loss: 0.3920, train acc: 0.8648, val loss: 0.7954, val acc: 0.7580
# step: 188, train loss: 0.3901, train acc: 0.8648, val loss: 0.7965, val acc: 0.7560
# step: 189, train loss: 0.3882, train acc: 0.8654, val loss: 0.7975, val acc: 0.7560
# step: 190, train loss: 0.3863, train acc: 0.8654, val loss: 0.7985, val acc: 0.7560
# step: 191, train loss: 0.3845, train acc: 0.8659, val loss: 0.7996, val acc: 0.7560
# step: 192, train loss: 0.3827, train acc: 0.8664, val loss: 0.8007, val acc: 0.7560
# step: 193, train loss: 0.3809, train acc: 0.8670, val loss: 0.8018, val acc: 0.7540
# step: 194, train loss: 0.3791, train acc: 0.8681, val loss: 0.8029, val acc: 0.7540
# step: 195, train loss: 0.3773, train acc: 0.8686, val loss: 0.8040, val acc: 0.7540
# step: 196, train loss: 0.3756, train acc: 0.8686, val loss: 0.8051, val acc: 0.7560
# step: 197, train loss: 0.3738, train acc: 0.8697, val loss: 0.8063, val acc: 0.7560
# step: 198, train loss: 0.3721, train acc: 0.8714, val loss: 0.8074, val acc: 0.7580
# step: 199, train loss: 0.3704, train acc: 0.8719, val loss: 0.8086, val acc: 0.7580

# %%
test_loss, test_acc = compute_loss(trained_model_state, trained_model_state.params, graph, graph_labels, one_hot_labels, graph_test_mask)
print(f'test loss: {test_loss:.4f}, test acc: {test_acc:.4f}')
accuracy_list.append(['CiteSeer', 'test', float(test_acc)])
# Out:
# test loss: 0.7778, test acc: 0.7680

# %% [markdown]
# ## Visualizing nodes before and after training

# %%
nodes_untrained = model_state.apply_fn(model_state.params, graph).nodes
z_nodes_untrained = TSNE(n_components=2).fit_transform(nodes_untrained)

nodes_trained = trained_model_state.apply_fn(trained_model_state.params, graph).nodes
z_nodes_trained = TSNE(n_components=2).fit_transform(nodes_trained)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].set_title('Before training')
axs[0].scatter(z_nodes_untrained[:,0], z_nodes_untrained[:,1], marker='o', color=np.array(plot_colors)[graph_labels])

axs[1].set_title('After training')
axs[1].scatter(z_nodes_trained[:,0], z_nodes_trained[:,1], marker='o', color=np.array(plot_colors)[graph_labels])

for ax in axs:
  ax.tick_params(axis='both',which='both',bottom=False,top=False,left=False,right=False,
            labelbottom=False,labeltop=False,labelleft=False,labelright=False);
  ax.set(xlabel=None, ylabel=None)
plt.show()

# %% [markdown]
# ## Plotting the results

# %%
df = pd.DataFrame(accuracy_list, columns=('Dataset', 'Split', 'Accuracy'))
sns.barplot(df,x='Dataset', y='Accuracy', hue='Split', palette="muted")
plt.show()
